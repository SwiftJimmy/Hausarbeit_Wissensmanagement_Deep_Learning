# %%
# Verbindung zum Google Drive aufbauen
from google.colab import drive
drive.mount('/content/drive')

# %%
#TensorBoard starten
# %reload_ext tensorboard
# %tensorboard --logdir "/content/drive/My Drive/models/research/object_detection/training/" --reload_multifile True
